# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np
import pandas as pd

# %%
train = pd.read_csv("train.csv", index_col='Name')
train.sample(10)
# Out:
#                                       PassengerId  Survived  Pclass     Sex  \
# Name
# Caldwell, Master. Alden Gates                  79         1       2    male
# Yasbeck, Mr. Antoni                           621         0       3    male
# Pasic, Mr. Jakob                              837         0       3    male
# Icard, Miss. Amelie                            62         1       1  female
# van Billiard, Mr. Austin Blyler               154         0       3    male
# Cann, Mr. Ernest Charles                       38         0       3    male
# Silvey, Mr. William Baird                     435         0       1    male
# Ilmakangas, Miss. Pieta Sofia                 730         0       3  female
# Roebling, Mr. Washington Augustus II          868         0       1    male
# Kraeff, Mr. Theodor                            43         0       3    male
#
#                                         Age  SibSp  Parch            Ticket  \
# Name
# ...

# %%
test = pd.read_csv("test.csv", index_col="Name")
test.sample(10)
# Out:
#                                                   PassengerId  Pclass     Sex  \
# Name
# Laroche, Miss. Louise                                    1188       2  female
# Karlsson, Mr. Julius Konrad Eugen                        1087       3    male
# Assam, Mr. Ali                                           1217       3    male
# Bjorklund, Mr. Ernst Herbert                              954       3    male
# Nilsson, Miss. Berta Olivia                              1089       3  female
# Rheims, Mr. George Alexander Lucien                      1182       1    male
# Kimball, Mrs. Edwin Nelson Jr (Gertrude Parsons)          936       1  female
# Peruschitz, Rev. Joseph Maria                            1056       2    male
# Dulles, Mr. William Crothers                             1223       1    male
# Dintcheff, Mr. Valtcho                                   1026       3    male
#
#                                                    Age  SibSp  Parch  \
# Name
# ...

# %%
X = train.drop('Survived', axis=1)
y = train['Survived']
X.shape, y.shape
# Out:
# ((891, 10), (891,))

# %%
from sklearn.impute import SimpleImputer

impX = SimpleImputer(strategy='most_frequent').fit_transform(X)
impdf = pd.DataFrame(impX ,columns=X.columns)
impdf.head()
# Out:
#   PassengerId Pclass     Sex Age SibSp Parch            Ticket     Fare  \
# 0           1      3    male  22     1     0         A/5 21171     7.25
# 1           2      1  female  38     1     0          PC 17599  71.2833
# 2           3      3  female  26     0     0  STON/O2. 3101282    7.925
# 3           4      1  female  35     1     0            113803     53.1
# 4           5      3    male  35     0     0            373450     8.05
#
#      Cabin Embarked
# 0  B96 B98        S
# 1      C85        C
# 2  B96 B98        S
# 3     C123        S
# 4  B96 B98        S

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
class MultiColumnLabelEncoder:
    
    def __init__(self, columns = None):
        self.columns = columns # list of column to encode
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        '''
        Transforms columns of X specified in self.columns using
        LabelEncoder(). If no columns specified, transforms all
        columns in X.
        '''
        
        output = X.copy()
        
        if self.columns is not None:
            for col in self.columns:
                output[col] = LabelEncoder().fit_transform(output[col])
        else:
            for colname, col in output.iteritems():
                output[colname] = LabelEncoder().fit_transform(col)
        
        return output
    def fit_transform(self, X, y=None):
        return self.fit(X, y).transform(X)
    
le = MultiColumnLabelEncoder()
X_le = le.fit_transform(impdf)
X_le.head()

# le = LabelEncoder()
# X_le = le.fit_transform(impdf)

# ohe = OneHotEncoder(sparse=False)
# X_ohe = ohe.fit_transform(impdf)

# X_ohe

# import category_encoders as ce
# ohe = ce.OneHotEncoder(handle_unknown='ignore', use_cat_names=True)
# X_ohe = ohe.fit_transform(impdf)
# X_ohe.head()
# Out:
#    PassengerId  Pclass  Sex  Age  SibSp  Parch  Ticket  Fare  Cabin  Embarked
# 0            0       2    1   28      1      0     523    18     47         2
# 1            1       0    0   51      1      0     596   207     81         0
# 2            2       2    0   34      0      0     669    41     47         2
# 3            3       0    0   47      1      0      49   189     55         2
# 4            4       2    1   47      0      0     472    43     47         2

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import make_pipeline

model = SVC()

param_grid = {'C': [0.001, 0.01, 0.1, 1, 5, 10, 50], 'gamma': [0.0001, 0.0005, 0.001, 0.005], 'kernel' : ['rbf']}
grid = GridSearchCV(model, param_grid)
grid.fit(X_le, y)
print(grid.best_params_)
# Out:
# c:\users\smkim\appdata\local\programs\python\python36-32\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}

# %%
model = grid.best_estimator_

imptest = SimpleImputer(strategy='most_frequent').fit_transform(test)
testdf = pd.DataFrame(imptest ,columns=test.columns)
test_le = MultiColumnLabelEncoder().fit_transform(testdf)
labels = model.predict(test_le)
testdf['Survived'] = labels

# %%
testdf.head()
# Out:
#   PassengerId Pclass     Sex   Age SibSp Parch   Ticket     Fare  \
# 0         892      3    male  34.5     0     0   330911   7.8292
# 1         893      3  female    47     1     0   363272        7
# 2         894      2    male    62     0     0   240276   9.6875
# 3         895      3    male    27     0     0   315154   8.6625
# 4         896      3  female    22     1     1  3101298  12.2875
#
#              Cabin Embarked  Survived
# 0  B57 B59 B63 B66        Q         1
# 1  B57 B59 B63 B66        S         1
# 2  B57 B59 B63 B66        Q         1
# 3  B57 B59 B63 B66        S         1
# 4  B57 B59 B63 B66        S         1

# %%
result = pd.read_csv("gender_submission.csv")
y_result = result['Survived']

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_result, labels)
# Out:
# 0.6076555023923444
